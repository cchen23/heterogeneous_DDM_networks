# %%
import numpy as np
import DDM_util as util
import networkx as nx
from IPython import display
# %matplotlib inline

# %%
num_individuals = 10
L = util.create_fullyconnected_graph(num_individuals)
util.draw_circle_graph(L)

# %%
num_individuals = 10
x0 = np.zeros([num_individuals, 1])
sigma_noise = np.ones([num_individuals, 1]) * 0.1
sigma = np.zeros([num_individuals, 1])

# %% [markdown]
# ## One Leader

# %%
leader_indices = [5]
leader_betas = [1]
beta = util.create_leaderfollower_beta(num_individuals, leader_indices, leader_betas)
dt = 0.001
T = 100
x_oneleader_nonoise = util.run_simulation(x0, beta, L, dt, sigma, T)

# %%
util.plot_discrepancy(x_oneleader_nonoise, [5])
# Out:
# centers [5]
# Total final discrepancy: 0.09
# Final discrepancy: [ 0.09]

# %%
leader_indices = [5]
leader_betas = [1]
beta = util.create_leaderfollower_beta(num_individuals, leader_indices, leader_betas)
dt = 0.001
T = 100
x_oneleader_noise = util.run_simulation(x0, beta, L, dt, sigma_noise, T)

# %%
util.plot_discrepancy(x_oneleader_noise, [5])
# Out:
# centers [5]
# Total final discrepancy: 22.23
# Final discrepancy: [ 22.22751829]

# %%
x_oneleader_noise_trial2 = util.run_simulation(x0, beta, L, dt, sigma_noise, T)

# %%
util.plot_discrepancy(x_oneleader_noise_trial2, [5])
# Out:
# centers [5]
# Total final discrepancy: 7.95
# Final discrepancy: [ 7.95375234]

# %%
x_oneleader_noise_trial3 = util.run_simulation(x0, beta, L, dt, sigma_noise, T)

# %%
util.plot_discrepancy(x_oneleader_noise_trial3, [5])
# Out:
# centers [5]
# Total final discrepancy: 4.12
# Final discrepancy: [ 4.11681757]

# %% [markdown]
# ## Two Leaders

# %%
leader_indices = [3,5]
leader_betas = [1,1]
beta = util.create_leaderfollower_beta(num_individuals, leader_indices, leader_betas)
dt = 0.001
T = 100
x_twoleaders_35_same_nonoise = util.run_simulation(x0, beta, L, dt, sigma, T)

# %%
util.plot_discrepancy(x_twoleaders_35_same_nonoise, [3, 5])
# Out:
# centers [3, 5]
# Total final discrepancy: 0.16
# Final discrepancy: [ 0.08  0.08]

# %%
leader_indices = [3,5]
leader_betas = [1,1]
beta = util.create_leaderfollower_beta(num_individuals, leader_indices, leader_betas)
dt = 0.001
T = 100
x_twoleaders_35_same_noise = util.run_simulation(x0, beta, L, dt, sigma_noise, T)

# %%
util.plot_discrepancy(x_twoleaders_35_same_noise, [3, 5])
# Out:
# centers [3, 5]
# Total final discrepancy: 9.70
# Final discrepancy: [ 2.48268374  7.21569027]

# %%
leader_indices = [3,5]
leader_betas = [1,-1]
beta = util.create_leaderfollower_beta(num_individuals, leader_indices, leader_betas)
dt = 0.001
T = 100
x_twoleaders_35_different_nonoise = util.run_simulation(x0, beta, L, dt, sigma, T)

# %%
util.plot_discrepancy(x_twoleaders_35_different_nonoise, [3,5])
# Out:
# centers [3, 5]
# Total final discrepancy: 0.24
# Final discrepancy: [ 0.12  0.12]

# %%
leader_indices = [3,5]
leader_betas = [1,-1]
beta = util.create_leaderfollower_beta(num_individuals, leader_indices, leader_betas)
dt = 0.001
T = 100
x_twoleaders_35_different_noise = util.run_simulation(x0, beta, L, dt, sigma_noise, T)

# %%
util.plot_discrepancy(x_twoleaders_35_different_noise, [3,5])
# Out:
# centers [3, 5]
# Total final discrepancy: 13.55
# Final discrepancy: [ 6.68202152  6.87066978]

# %%
leader_indices = [3,5]
leader_betas = [1,-1]
beta = util.create_leaderfollower_beta(num_individuals, leader_indices, leader_betas)
dt = 0.001
T = 100
x_twoleaders_35_different_noise_trial2 = util.run_simulation(x0, beta, L, dt, sigma_noise, T)
